# %% [markdown]
# <a href="https://colab.research.google.com/github/tjain858/IMDB-EDA/blob/main/IMDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_excel("/content/drive/MyDrive/IMDB Dataset/imdb_data.xlsx")

# %% [markdown]
# Using shape we can see our Dataset have how many Rows and Columns.

# %%
df.shape
# Out:
# (3000, 23)

# %% [markdown]
# Using head we can see first 5 records of Dataset.

# %%
df.head()
# Out:
#     id                              belongs_to_collection      budget  \
# 0  1.0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000.0
# 1  2.0  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000.0
# 2  3.0                                                NaN   3300000.0
# 3  4.0                                                NaN   1200000.0
# 4  5.0                                                NaN         0.0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %% [markdown]
# Now let's see tail of the Dataset using tail to get the clarity about data.

# %%
df.tail(10)
# Out:
#           id                              belongs_to_collection      budget  \
# 2990  2991.0                                                NaN         0.0
# 2991  2992.0  [{'id': 107469, 'name': 'Save The Last Dance C...  13000000.0
# 2992  2993.0                                                NaN   1135654.0
# 2993  2994.0                                                NaN  60000000.0
# 2994  2995.0                                                NaN         0.0
# 2995  2996.0                                                NaN         0.0
# 2996  2997.0                                                NaN         0.0
# 2997  2998.0                                                NaN  65000000.0
# 2998  2999.0                                                NaN  42000000.0
# 2999  3000.0                                                NaN  35000000.0
#
#                                                  genres  \
# 2990  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# ...

# %% [markdown]
# Now we can see non null count and data types of clumns using info.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   float64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   float64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %% [markdown]
# describe method gives all over descrptive summary of Dataset.

# %%
df.describe()
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %% [markdown]
# Using iloc we can get Columns and rows of particular index.

# %%
df.iloc[:10,0:4]
# Out:
#      id                              belongs_to_collection      budget  \
# 0   1.0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000.0
# 1   2.0  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000.0
# 2   3.0                                                NaN   3300000.0
# 3   4.0                                                NaN   1200000.0
# 4   5.0                                                NaN         0.0
# 5   6.0                                                NaN   8000000.0
# 6   7.0                                                NaN  14000000.0
# 7   8.0                                                NaN         0.0
# 8   9.0  [{'id': 256377, 'name': 'The Muppet Collection...         0.0
# 9  10.0                                                NaN   6000000.0
#
#                                               genres
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...

# %% [markdown]
# Loc get rows and colums with particular labels from index.

# %%
df.loc[10:20,['budget','imdb_id']]
# Out:
#          budget    imdb_id
# 10    1000000.0  tt0075148
# 11          0.0  tt0093857
# 12   15000000.0  tt0169547
# 13   53000000.0  tt0377471
# 14  102000000.0  tt0181689
# 15     500000.0  tt1129437
# 16   26000000.0  tt0421239
# 17          0.0  tt1700845
# 18    8000000.0  tt1487118
# 19   32000000.0  tt0388482
# 20   80000000.0  tt0120738

# %% [markdown]
# We can also get the colums withou using loc or iloc

# %%
df[['budget','imdb_id']]
# Out:
#           budget    imdb_id
# 0     14000000.0  tt2637294
# 1     40000000.0  tt0368933
# 2      3300000.0  tt2582802
# 3      1200000.0  tt1821480
# 4            0.0  tt1380152
# ...          ...        ...
# 2995         0.0  tt0109403
# 2996         0.0  tt2364975
# 2997  65000000.0  tt0116908
# 2998  42000000.0  tt0343135
# 2999  35000000.0  tt1600195
#
# [3000 rows x 2 columns]

# %% [markdown]
# To check the name of all columns we can use column method.

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %% [markdown]
# If we have to get the data foe Ebglish movies.

# %%
english_movies=df[df['original_language'] == 'en']
english_movies.head()
# Out:
#     id                              belongs_to_collection      budget  \
# 0  1.0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000.0
# 1  2.0  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000.0
# 2  3.0                                                NaN   3300000.0
# 5  6.0                                                NaN   8000000.0
# 6  7.0                                                NaN  14000000.0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#                              homepage    imdb_id original_language  \
# 0                                 NaN  tt2637294                en
# 1                                 NaN  tt0368933                en
# ...

# %% [markdown]
# Add column whose runtime is just half runtime of original

# %%
df['Half_runtime']=df['runtime']*0.5

# %%
df[['runtime','Half_runtime']]
# Out:
#       runtime  Half_runtime
# 0        93.0          46.5
# 1       113.0          56.5
# 2       105.0          52.5
# 3       122.0          61.0
# 4       118.0          59.0
# ...       ...           ...
# 2995    102.0          51.0
# 2996    102.0          51.0
# 2997    120.0          60.0
# 2998     90.0          45.0
# 2999    106.0          53.0
#
# [3000 rows x 2 columns]
